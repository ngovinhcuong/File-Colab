# %% [markdown]
# <img src="https://stablediffusion.life/wp-content/uploads/2023/04/Website.jpg" alt="Banner" width="100%">
#
# ## **Stable Diffusion - Chia Sẻ Đam Mê - Công cụ Download**
# [![Badge with Link](https://img.shields.io/badge/Website-stablediffusion.life-Color?style=for-the-badge&logo=firefox&logoColor=green)](https://stablediffusion.life/) &nbsp; &nbsp;
# [![Badge with Link](https://img.shields.io/badge/Group-stable_diffusion_chia_se_dam_me-%230080FF?style=for-the-badge&logo=facebook&logoColor=0080ff)](https://www.facebook.com/groups/stablediffusionvietnam) &nbsp; &nbsp;
# [![Badge with Link](https://img.shields.io/badge/Youtube-stable_diffusion_chia_se_dam_me-%23ff0000?style=for-the-badge&logo=youtube&logoColor=ff0000)](https://www.youtube.com/@hoangdiffusion)&nbsp; &nbsp;
# [![Badge with Link](https://img.shields.io/badge/donate-thank_you-%23ff6600?style=for-the-badge&logo=coins&logoColor=ff0000)](https://stablediffusion.life/donate/)&nbsp; &nbsp;
# [![Badge with Link](https://img.shields.io/badge/phone-RC_hoang_0988_902_723-%23ff6600?style=for-the-badge&logo=&logoColor=ff0000)](https://stablediffusion.life/donate/)
#
#
# ---
# ## **Hướng dẫn:**
# *   Chạy Phần 1 để cho phép truy cập Drive
# *   Lấy link trực tiếp từ các trang download
# *   Thay đổi thư mục lưu trữ và tên model, lora tuỳ ý (Chú ý giữ phần đuôi mở rộng)
# *   Phần 2, 3 có vai trò như nhau, tách ra cho đỡ nhầm thư mục!
# *   Sau khi điền đủ thông tin thì nhấn chạy lệnh tương ứng, có dấu tích là thành công
# *   Tấc độ download nhanh hơn là tải về máy tính rồi lại upload lên Drive

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/Phần_1-Kết_Nối_Drive-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/)
from google.colab import drive
drive.mount('/content/drive')

# !apt-get -y install -qq aria2

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/Phần_2-Tải_Model-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/)
model_url = "https://civitai.com/api/download/models/11745" #@param {type:"string"}
model_folder = "/content/drive/MyDrive/SD-ChiaSeDamMe/Model" #@param {type:"string"}
model_name = "chilloutmix_NiPrunedFp32Fix.safetensors" #@param {type:"string"}
model_url = f"\"{model_url}\""
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {model_url} -d {model_folder} -o {model_name}

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/Phần_3-Tải_Lora-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/)
lora_url = "https://civitai.com/api/download/models/19793" #@param {type:"string"}
lora_folder = "/content/drive/MyDrive/SD-ChiaSeDamMe/Lora" #@param {type:"string"}
lora_name = "a0d4ivn.safetensors" #@param {type:"string"}
lora_url = f"\"{lora_url}\""
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {lora_url} -d {lora_folder} -o {lora_name}
