# %% [markdown]
# <img src="https://stablediffusion.life/wp-content/uploads/2023/04/Website.jpg" alt="Banner" width="100%">
#
# ## **Stable Diffusion - Chia Sẻ Đam Mê - 1 Click - New Update**
# [![Badge with Link](https://img.shields.io/badge/Website-stablediffusion.life-Color?style=for-the-badge&logo=firefox&logoColor=green)](https://stablediffusion.life/) &nbsp; &nbsp;
# [![Badge with Link](https://img.shields.io/badge/Group-stable_diffusion_chia_se_dam_me-%230080FF?style=for-the-badge&logo=facebook&logoColor=0080ff)](https://www.facebook.com/groups/stablediffusionvietnam) &nbsp; &nbsp;
# [![Badge with Link](https://img.shields.io/badge/Youtube-stable_diffusion_chia_se_dam_me-%23ff0000?style=for-the-badge&logo=youtube&logoColor=ff0000)](https://www.youtube.com/@hoangdiffusion)&nbsp; &nbsp;
# [![Badge with Link](https://img.shields.io/badge/donate-thank_you-%23ff6600?style=for-the-badge&logo=coins&logoColor=ff0000)](https://stablediffusion.life/donate/)&nbsp; &nbsp;
# [![Badge with Link](https://img.shields.io/badge/phone-RC_hoang_0988_902_723-%23ff6600?style=for-the-badge&logo=&logoColor=ff0000)](https://stablediffusion.life/donate/)
#
#
# ---
# ## **Hướng dẫn:**
# *   Click Runtime trên thanh Menu/ Chọn Run All để chạy (Hoặc Alt+F9)
# *   Chuyển giao diện theme dark, các bạn thêm vào địa chỉ dạng như sau **gradio.live/?__theme=dark**, rồi enter!

# %% [markdown]
# ___

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/PHẦN_1-KHỞI_TẠO_MÔI_TRƯỜNG-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/) <br>
#@markdown *Chọn kết nối với Drive khi có yêu cầu*
from IPython.display import clear_output, display, HTML
import os
import time
from datetime import timedelta
from google.colab import drive
from IPython.utils import capture
from subprocess import getoutput
from urllib.parse import unquote
from google.colab.output import eval_js
import shutil

# %cd /content
drive.mount('/content/drive')

# Clear the output to keep the notebook clean
clear_output()
# Print the success message
print("✓ Kết thúc", "Kết nối với Drive thành công")
#================================================================>
# Sao chép bộ Stable Diffusion vào Colab
# !git clone --depth=1 https://github.com/ngovinhcuong/SD-CSDM-1Click-Colab /content/SD-CSDM
# %cd /content/SD-CSDM/
# !git pull
clear_output()

# Cài đặt môi trường
# %env TF_CPP_MIN_LOG_LEVEL=1
# !apt -y update -qq
# !wget http://launchpadlibrarian.net/367274644/libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/google-perftools_2.5-2.2ubuntu3_all.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb \
      https://launchpad.net/ubuntu/+source/google-perftools/2.5-2.2ubuntu3/+build/14795286/+files/libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb
# !apt -y install -qq libunwind8-dev aria2 libcairo2-dev pkg-config python3-dev
# !dpkg -i *.deb
# %env LD_PRELOAD=libtcmalloc.so
# !rm *.deb
clear_output()

# !pip install --use-feature=fast-deps -r requirements.txt
# !pip install numpy==1.23.5 --upgrade
# !pip install wget
clear_output()

# Tạo thư mục Stable-diffusion trong models
# %cd /content/SD-CSDM/models/
# !mkdir -p Stable-diffusion
# Tải model Chilloutmix
# %cd /content/SD-CSDM/models/Stable-diffusion/
# !wget --content-disposition --quiet https://huggingface.co/ngocuong/ModelsDownload/resolve/main/chilloutmix_NiPrunedFp32Fix.safetensors

# %cd /content/drive/MyDrive/

# !mkdir /content/drive/MyDrive/SD-ChiaSeDamMe/
# !mkdir /content/drive/MyDrive/SD-ChiaSeDamMe/outputs
# !mkdir /content/drive/MyDrive/SD-ChiaSeDamMe/Model
# !mkdir /content/drive/MyDrive/SD-ChiaSeDamMe/Lora
# !mkdir /content/drive/MyDrive/SD-ChiaSeDamMe/Setting

# Clear the output to keep the notebook clean
clear_output()
# Print the success message
print("✓ Kết thúc", "Khởi tạo môi trường và tải model Chilloutmix thành công")

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/PHẦN_2-CÀI_ĐẶT_EXTENSIONS-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/)


# %cd /content/SD-CSDM/extensions-builtin/
# !git clone https://github.com/YKefasu/sd-artists-ui-tweak sd-artists-ui-tweak
# !git clone https://tinyurl.com/sd-controlnet sd-controlnet
# !git clone https://tinyurl.com/infinite-image-browsing infinite-image-browsing
# !git clone https://github.com/Iyashinouta/sd-model-downloader sd-model-downloader
clear_output()

# %cd /content/SD-CSDM/extensions/
# !git clone https://tinyurl.com/sd-huggingface huggingface
# !git clone https://tinyurl.com/additional-networks additional-networks
# !git clone https://github.com/fkunn1326/openpose-editor openpose-editor
# !git clone https://tinyurl.com/depth-lib depth-lib
# !git clone https://github.com/hnmr293/posex posex
# !git clone https://tinyurl.com/3d-open-pose-editor 3d-open-pose-editor
# !git clone https://tinyurl.com/sd-deforum sd-deforum
# !git clone https://tinyurl.com/sd-two-shot two-shot
# !git clone https://tinyurl.com/aspect-ratio-helper aspect-ratio-helper
# !git clone https://tinyurl.com/asymmetric-tiling asymmetric-tiling
# !git clone https://tinyurl.com/tagcomplete tagcomplete
# !git clone https://tinyurl.com/sd-SAG sd_SAG
# !git clone https://github.com/Coyote-A/ultimate-upscale-for-automatic1111 ultimate-upscale-for-automatic1111
# !git clone https://github.com/richrobber2/canvas-zoom canvas-zoom
# !git clone https://github.com/Tsukreya/Umi-AI-debloat Umi-AI
# !git clone https://github.com/Bing-su/adetailer adetailer
# !git clone https://github.com/CiaraStrawberry/TemporalKit TemporalKit
# !git clone https://github.com/Extraltodeus/depthmap2mask depthmap2mask
# !git clone https://github.com/ngovinhcuong/ghepmat2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/datasets/ngocuong/Ghepmat/resolve/main/models/inswapper_128.onnx -d /content/SD-CSDM/extensions/ghepmat2/models -o inswapper_128.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/SD-CSDM/models/ESRGAN -o 4x-UltraSharp.pth
clear_output()

# %cd /content/SD-CSDM/repositories
# !git clone https://github.com/isl-org/MiDaS MiDaS

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Kết thúc", "Cài đặt Extensions thành công")

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/PHẦN_3-CÀI_ĐẶT_CONTROLNET-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/) <br>
#@markdown  *Ghi chú: Chọn Model Controlnet phù hợp, Chọn toàn bộ là 24GB*

import os
import urllib.request

# Function to check if the folder name is the same as the new folder name
def is_folder_name_same(folder_path, new_folder_name):
    folder_name = os.path.basename(folder_path)
    return folder_name == new_folder_name

# Path to the controlnet-rename.txt file
txt_file_path = "/content/SD-CSDM/html/controlnet-rename-back.txt"

# Path to the folder containing the renamed folder
folder_path = "/content/SD-CSDM/extensions-builtin"

# Read the contents of the txt file
with open(txt_file_path, 'r') as file:
    new_folder_name = file.read().strip()

# Check if the folder name is already the same as the new folder name
if is_folder_name_same(folder_path, new_folder_name):
    print("Folder name is already the same. Skipping the renaming process.")
else:
    # Rename the renamed folder back to "sd-controlnet"
    old_folder_path = os.path.join(folder_path, new_folder_name)
    new_folder_path = os.path.join(folder_path, "sd-controlnet")

    # Check if the renamed folder exists before renaming
    if os.path.exists(old_folder_path):
        os.rename(old_folder_path, new_folder_path)
        print(f"Folder renamed from '{new_folder_name}' to 'sd-controlnet'.")
    else:
        print(f"The folder does not exist.")

clear_output()

Model = "None" #@param ["None", "Canny", "Depth", "Lineart", "MLSD", "Normal", "OpenPose", "Scribble", "Seg", "ip2p", "Shuffle", "Inpaint", "Softedge", "Lineart_Anime", "Brightness", "Illumination", "Tile", "All Models (21GB)"]

model_urls = {
    "Canny": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth',
    "Depth": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth',
    "Lineart": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth',
    "MLSD": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd.pth',
    "Normal": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae.pth',
    "OpenPose": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth',
    "Scribble": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble.pth',
    "Seg": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth',
    "ip2p": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth',
    "Shuffle": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle.pth',
    "Inpaint": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth',
    "Softedge": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth',
    "Lineart_Anime": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime.pth',
    "Brightness": 'https://huggingface.co/ngocuong/Controlnet/resolve/main/control_v1p_sd15_brightness.safetensors',
    "Illumination": 'https://huggingface.co/ngocuong/Controlnet/resolve/main/control_v1p_sd15_illumination.safetensors',
    "Tile": 'https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth'
}

output_path = "/content/SD-CSDM/extensions-builtin/sd-controlnet/models/"

os.makedirs(output_path, exist_ok=True)  # Create the output directory if it doesn't exist

def download_model(model_url, output_path):
    filename = os.path.basename(model_url)
    output_file = os.path.join(output_path, filename)
    urllib.request.urlretrieve(model_url, output_file)
    return filename

if Model == "All Models (21GB)":
    for model in model_urls:
        model_url = model_urls[model]
        download_model(model_url, output_path)
    print("✓ Kết thúc", "Tải toàn bộ Model Controlnet thành công")
elif Model != "None":
    model_url = model_urls.get(Model)
    download_model(model_url, output_path)
    print("✓ Kết thúc", "Không cần tải Model Controlnet thành công")
else:
    clear_output()
    print("Hoàn tất tải Model Controlnet")
# =======================================================>
# Tải VAE Collection & Negtive Embedings

# %cd /content/SD-CSDM/models
# !mkdir -p embeddings/negative
# %cd /content/SD-CSDM/models/embeddings/negative/
# !git clone --quiet https://huggingface.co/embed/negative

# %cd /content/SD-CSDM/models/
# !mkdir -p VAE
# %cd /content/SD-CSDM/models/VAE/
# !git clone --quiet https://huggingface.co/Kefasu/sd-vae-collection /content/SD-CSDM/models/VAE/

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Kết thúc", "Tải VAE và Negtive Embedings thành công")

# =======================================================>
# Cài đặt FFmpeg for Temporalkit Extension

from IPython.display import clear_output
# !sudo curl -L https://github.com/BtbN/FFmpeg-Builds/releases/download/latest/ffmpeg-master-latest-linux64-gpl.tar.xz -o /usr/local/bin/ffmpeg.tar.xz
clear_output()
# %cd /usr/local/bin/
clear_output()
!7z e /usr/local/bin/ffmpeg.tar.xz
clear_output()
!7z e /usr/local/bin/ffmpeg.tar
clear_output()
# !sudo chmod a+rx /usr/local/bin/ffmpeg
clear_output()
# %cd /content/
# !sudo curl -L https://mkvtoolnix.download/appimage/MKVToolNix_GUI-70.0.0-x86_64.AppImage -o /usr/local/bin/MKVToolNix_GUI-70.0.0-x86_64.AppImage
# !sudo chmod u+rx /usr/local/bin/MKVToolNix_GUI-70.0.0-x86_64.AppImage
# !sudo ln -s /usr/local/bin/MKVToolNix_GUI-70.0.0-x86_64.AppImage /usr/local/bin/mkvmerge
# !sudo chmod a+rx /usr/local/bin/mkvmerge
clear_output()

# Download latest FFmpeg static build.
exist = !which ffmpeg
if not exist:
  # !curl https://johnvansickle.com/ffmpeg/releases/ffmpeg-release-amd64-static.tar.xz -o ffmpeg.tar.xz \
     && tar -xf ffmpeg.tar.xz && rm ffmpeg.tar.xz
  ffmdir = !find . -iname ffmpeg-*-static
  path = %env PATH
  path = path + ':' + ffmdir[0]
  # %env PATH $path

# !which ffmpeg
# !pip install ffmpy
clear_output()
print("✓ Kết thúc", "Cài đặt FFmpeg for Temporalkit Extension thành công")

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/PHẦN_4.1-DOWNLOAD_MODEL/CHECKPOINT-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/) <br>
#@markdown *Tải Models/Checkpoint (DirectLink URL), để trống nếu không cần tải - Mặc định có Model Chilloutmix, Model tải về ổ Colab.*

# %cd /content/SD-CSDM/models/Stable-diffusion/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

DirectLink_URL_2 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_2

DirectLink_URL_3 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_3

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Kết thúc", "Hoàn tất cài đặt Model")

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/PHẦN_4.2-DOWNLOAD_LORA-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/)

# %cd /content/SD-CSDM/models/
# !mkdir -p Lora
# %cd /content/SD-CSDM/models/Lora/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/PHẦN_4.3-DOWNLOAD_LOCON_or_LYCORIS-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/)

# %cd /content/SD-CSDM/models/
# !mkdir -p LyCORIS
# %cd /content/SD-CSDM/models/LyCORIS/
DirectLink_URL_1 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_1

DirectLink_URL_2 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_2

DirectLink_URL_3 = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL_3

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/PHẦN_4.4-DOWNLOAD_TEXTUAL_INVERSION-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/)

# %cd /content/SD-CSDM/models/
# !mkdir -p embeddings
# %cd /content/SD-CSDM/models/embeddings/
DirectLink_URL = ""  # @param {'type': 'string'}
# !wget --content-disposition $DirectLink_URL

# Clear the output to keep the notebook clean
clear_output()

# Print the success message
print("✓ Done", "success")

# %%
#@markdown [![Badge with Link](https://img.shields.io/badge/PHẦN_5-CHẠY_STABLE_DIFFUSION-%2300A8E1?style=for-the-badge&logo=firefox&logoColor=00A8E1)](https://stablediffusion.life/)<BR>
#@markdown *Không chạy link "trycloudflare.com", vui lòng chạy link "gradio.live"*

import os
from IPython.display import clear_output, display, HTML
# Tạo liên kết tượng trưng mềm từ drive với ổ cứng colab
# !ln -s /content/drive/MyDrive/SD-ChiaSeDamMe/Model /content/SD-CSDM/models/Stable-diffusion
# !ln -s /content/drive/MyDrive/SD-ChiaSeDamMe/Lora /content/SD-CSDM/models/Lora

# Path to the controlnet-rename.txt file
txt_file_path = "/content/SD-CSDM/html/controlnet-rename.txt"
# Path to the folder containing folder1
folder_path = "/content/SD-CSDM/extensions-builtin"

# Read the contents of the txt file
with open(txt_file_path, 'r') as file:
    new_folder_name = file.read().strip()

# Rename the folder to the new folder name
old_folder_path = os.path.join(folder_path, "sd-controlnet")
new_folder_path = os.path.join(folder_path, new_folder_name)

# Check if the old folder exists before renaming
if os.path.exists(old_folder_path):
    os.rename(old_folder_path, new_folder_path)
    print(f"Folder renamed from 'sd-controlnet' to '{new_folder_name}'.")
else:
    print("The folder does not exist.")

# %cd /content/SD-CSDM/
# !wget --quiet https://raw.githubusercontent.com/YKefasu/sdiffusion-scripts/main/run_n_times.py -O /content/SD-CSDM/scripts/run_n_times.py
clear_output()

# Function to play audio in the background
import threading

audio_url = "https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a"

# Function to play audio in the background
def play_audio(url):
    display(HTML(f'<audio src="{url}" controls autoplay style="display:none"></audio>'))

# Create a separate thread for playing audio
audio_thread = threading.Thread(target=play_audio, args=(audio_url,))
audio_thread.start()

# Continue executing your code here

COMMANDLINE_ARGS="--no-hashing --share --theme dark --allow-code --insecure --no-download --cloudflared"
REQS_FILE="requirements.txt"
# !python launch.py {COMMANDLINE_ARGS}
